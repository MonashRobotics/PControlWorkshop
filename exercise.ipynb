# %%
from helper import SimpleRobot
from matplotlib import pyplot as plt

# %%
robot = SimpleRobot()

# %%
fig, ax = plt.subplots()


x_desired = 5

for i in range(30):
    # Enter your equation here to control the robot velocity
    v = 2
    # Hint, the robot position is stored in the variable robot.x

    # Try to play around with the parameters of your equation to see how this effects the robot

    robot.drive(v)
    robot.plot(ax,color='C1')
